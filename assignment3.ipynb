# %% [markdown]
# <a href="https://colab.research.google.com/github/paladugulashruthi/ASSIGNMENT3/blob/master/assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.read mobile dataset using pandas, and preprocess it (fill null values).

# %%
import pandas as pd

# %%
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
print(a)
a.describe()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 2           0         9        55  ...              2500             164         0
# 3           0         8        55  ...              3000             165         1
# 4           1         1        55  ...              3000             165         0
# ..        ...       ...       ...  ...               ...             ...       ...
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# ...

# %%
a.isnull()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0       False     False     False  ...             False           False     False
# 1       False     False     False  ...             False           False     False
# 2       False     False     False  ...             False           False     False
# 3       False     False     False  ...             False           False     False
# 4       False     False     False  ...             False           False     False
# ..        ...       ...       ...  ...               ...             ...       ...
# 104     False     False     False  ...             False           False     False
# 105     False     False     False  ...             False           False     False
# 106     False     False     False  ...             False           False     False
# 107     False     False     False  ...             False           False     False
# ...

# %%
a.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
a['weight']=a['weight'].fillna(a['weight'].mean())
a['primary_camera_resolution']=a['primary_camera_resolution'].fillna(a['primary_camera_resolution'].mean())
a['front_camera_resolution']=a['front_camera_resolution'].fillna(a['front_camera_resolution'].mean())
a['talk_time']=a['talk_time'].fillna(a['talk_time'].mean())
a['phone_height']=a['phone_height'].fillna(a['phone_height'].mean())
a['no_of_reviews_in_gsmarena_in_week']=a['no_of_reviews_in_gsmarena_in_week'].fillna(a['no_of_reviews_in_gsmarena_in_week'].mean())
a['stand_by_time']=a['stand_by_time'].fillna(a['stand_by_time'].mean())
a['video_resolution']=a['video_resolution'].fillna(a['video_resolution'].mean())

# %%
a.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %% [markdown]
# 2.Draw correlation graph for mobile price with all attributes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,0:1]
plt.xlabel("price")
plt.ylabel("sim_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,1:2]
plt.xlabel("price")
plt.ylabel("aperture")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,2:3]
plt.xlabel("price")
plt.ylabel("gpu_rank")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,4:5]
plt.xlabel("price")
plt.ylabel("stand_by_time")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,5:6]
plt.xlabel("price")
plt.ylabel("processor_frequency")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,6:7]
plt.xlabel("price")
plt.ylabel("thickness")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,7:8]
plt.xlabel("price")
plt.ylabel("flash_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,8:9]
plt.xlabel("price")
plt.ylabel("front_camera_resolution")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,9:10]
plt.xlabel("price")
plt.ylabel("auto_focus")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,10:11]
plt.xlabel("price")
plt.ylabel("screen_size")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,11:12]
plt.xlabel("price")
plt.ylabel("frames_per_second")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,12:13]
plt.xlabel("price")
plt.ylabel("FM")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,13:14]
plt.xlabel("price")
plt.ylabel("no_of_reviews_in_gsmarena_in_week")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,14:15]
plt.xlabel("price")
plt.ylabel("OS")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,15:16]
plt.xlabel("price")
plt.ylabel("phine_height")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,16:17]
plt.xlabel("price")
plt.ylabel("screen_protection")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,17:18]
plt.xlabel("price")
plt.ylabel("sim_size")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,19:20]
plt.xlabel("price")
plt.ylabel("talk_time")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,20:21]
plt.xlabel("price")
plt.ylabel("vedio_resolution")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,21:22]
plt.xlabel("price")
plt.ylabel("display_resolution")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,22:23]
plt.xlabel("price")
plt.ylabel("removable_battery")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,23:24]
plt.xlabel("price")
plt.ylabel("display_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,24:25]
plt.xlabel("price")
plt.ylabel("primary_camera")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,25:26]
plt.xlabel("price")
plt.ylabel("battery_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,26:27]
plt.xlabel("price")
plt.ylabel("ram_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,27:28]
plt.xlabel("price")
plt.ylabel("internal_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,28:29]
plt.xlabel("price")
plt.ylabel("brand_rank")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,29:30]
plt.xlabel("price")
plt.ylabel("no_of_cores")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,30:31]
plt.xlabel("price")
plt.ylabel("micro_sd_slot")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,31:32]
plt.xlabel("price")
plt.ylabel("screen_pixel_density")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,32:33]
plt.xlabel("price")
plt.ylabel("water_proof_rate")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,33:34]
plt.xlabel("price")
plt.ylabel("phone_width")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,34:35]
plt.xlabel("price")
plt.ylabel("expandable_memory")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
 
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,35:36]
plt.xlabel("price")
plt.ylabel("version")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,36:37]
plt.xlabel("price")
plt.ylabel("usb_type")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,37:38]
plt.xlabel("price")
plt.ylabel("battery_capacity")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,38:39]
plt.xlabel("price")
plt.ylabel("processor_rank")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/pappu/pappu/Assignments/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,39:40]
plt.xlabel("price")
plt.ylabel("is_linked")
plt.plot(x,y,'g')
plt.scatter(x,y)

# %% [markdown]
# 3.Compute outer product of 2 vectors. Eg:
#
# original matrix: [[1, 0], [0, 1]] [[1, 2], [3, 4]] Outer product of the said two vectors: [[1 2 3 4] [0 0 0 0] [0 0 0 0] [1 2 3 4]]

# %%
import numpy as s
p=[[1,0],[0,1]]
q=[[1,2],[3,4]]
print("ORIGINAL MATRIX IS:")
print(p)
print(q)
print("THE OUTER PRODUCT OF GIVEN VECTORS IS :  \n",s.outer(p,q))
# Out:
# ORIGINAL MATRIX IS:
# [[1, 0], [0, 1]]
# [[1, 2], [3, 4]]
# THE OUTER PRODUCT OF GIVEN VECTORS IS :
#  [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %% [markdown]
# 4.Write a NumPy program to compute the condition number of a given matrix. Original matrix: [[1 2] [3 4]] Condition number of the said matrix: 14.9330343737

# %%
 import numpy as np
m = np.array([[1,2],[3,4]])
print("Original matrix:")
print(m)
result =  np.linalg.cond(m)
print("Condition number of the said matrix:")
print(result)
# Out:
# Original matrix:
# [[1 2]
#  [3 4]]
# Condition number of the said matrix:
# 14.933034373659268

# %% [markdown]
# 5.write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
 t=s.outer(p,q)
print(s.trace(t))
# Out:
# 5
